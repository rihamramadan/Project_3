# %%
# Dependencies
import numpy as np
import pandas as pd
import os

# %%
enron = pd.read_csv(os.path.join('enron_salary_data.csv'))
enron_df = pd.DataFrame(enron)
enron_df.head()
# Out:
#                name    salary  to_messages  deferral_payments  total_payments  \
# 0        METTS MARK  365788.0        807.0                NaN       1061827.0
# 1     BAXTER JOHN C  267102.0          NaN          1295738.0       5634343.0
# 2    ELLIOTT STEVEN  170941.0          NaN                NaN        211725.0
# 3  CORDES WILLIAM R       NaN        764.0                NaN             NaN
# 4    HANNON KEVIN P  243293.0       1045.0                NaN        288682.0
#
#    exercised_stock_options      bonus  restricted_stock  \
# 0                      NaN   600000.0          585062.0
# 1                6680544.0  1200000.0         3942714.0
# 2                4890344.0   350000.0         1788391.0
# 3                 651850.0        NaN          386335.0
# 4                5538001.0  1500000.0          853064.0
#
#    shared_receipt_with_poi  restricted_stock_deferred  \
# 0                    702.0                        NaN
# ...

# %%
enron_df = enron_df[enron_df.name != 'TOTAL']

# %%
enron_df.name.count()
# Out:
# 145

# %%
drop_columns = ['name', 'email_address']
enron_df.drop(drop_columns, inplace=True, axis=1)

# %%
enron_df.head()
# Out:
#      salary  to_messages  deferral_payments  total_payments  \
# 0  365788.0        807.0                NaN       1061827.0
# 1  267102.0          NaN          1295738.0       5634343.0
# 2  170941.0          NaN                NaN        211725.0
# 3       NaN        764.0                NaN             NaN
# 4  243293.0       1045.0                NaN        288682.0
#
#    exercised_stock_options      bonus  restricted_stock  \
# 0                      NaN   600000.0          585062.0
# 1                6680544.0  1200000.0         3942714.0
# 2                4890344.0   350000.0         1788391.0
# 3                 651850.0        NaN          386335.0
# 4                5538001.0  1500000.0          853064.0
#
#    shared_receipt_with_poi  restricted_stock_deferred  total_stock_value  \
# 0                    702.0                        NaN           585062.0
# 1                      NaN                        NaN         10623258.0
# ...

# %%
enron_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 145
# Data columns (total 20 columns):
# salary                       94 non-null float64
# to_messages                  86 non-null float64
# deferral_payments            38 non-null float64
# total_payments               124 non-null float64
# exercised_stock_options      101 non-null float64
# bonus                        81 non-null float64
# restricted_stock             109 non-null float64
# shared_receipt_with_poi      86 non-null float64
# restricted_stock_deferred    17 non-null float64
# total_stock_value            125 non-null float64
# expenses                     94 non-null float64
# loan_advances                3 non-null float64
# from_messages                86 non-null float64
# other                        92 non-null float64
# from_this_person_to_poi      86 non-null float64
# poi                          145 non-null bool
# director_fees                16 non-null float64
# ...

# %%
#Keeps only columns that have ~70% of the fields as non-null
slim_enron_df = enron_df.dropna(thresh=14)
slim_enron_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 4 to 145
# Data columns (total 20 columns):
# salary                       57 non-null float64
# to_messages                  57 non-null float64
# deferral_payments            15 non-null float64
# total_payments               57 non-null float64
# exercised_stock_options      50 non-null float64
# bonus                        53 non-null float64
# restricted_stock             56 non-null float64
# shared_receipt_with_poi      57 non-null float64
# restricted_stock_deferred    6 non-null float64
# total_stock_value            56 non-null float64
# expenses                     51 non-null float64
# loan_advances                2 non-null float64
# from_messages                57 non-null float64
# other                        57 non-null float64
# from_this_person_to_poi      57 non-null float64
# poi                          57 non-null bool
# director_fees                0 non-null float64
# ...

# %%
slim_enron_df.to_csv('enron_test_data.csv', index=False)

# %%
slim_enron_df.head()
# Out:
#       salary  to_messages  deferral_payments  total_payments  \
# 4   243293.0       1045.0                NaN        288682.0
# 7   370448.0       2355.0                NaN       4099771.0
# 9   197091.0       1238.0          1130036.0       1737629.0
# 12  248546.0       2475.0                NaN       2014835.0
# 16  288542.0       1758.0            27610.0       1490344.0
#
#     exercised_stock_options      bonus  restricted_stock  \
# 4                 5538001.0  1500000.0          853064.0
# 7                 1104054.0  2600000.0          558801.0
# 9                  880290.0   400000.0          409554.0
# 12                 765313.0   850000.0          189041.0
# 16                      NaN  1200000.0          698242.0
#
#     shared_receipt_with_poi  restricted_stock_deferred  total_stock_value  \
# 4                    1035.0                        NaN          6391065.0
# 7                    2228.0                        NaN          1662855.0
# ...
