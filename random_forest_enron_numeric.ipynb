# %%
from sklearn import tree
import pandas as pd
import os
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(os.path.join("enron_salary_numeric.csv"))
enron_df = pd.DataFrame(df)
enron_df.head()
# Out:
#                name    salary  to_messages  deferral_payments  total_payments  \
# 0        METTS MARK  365788.0        807.0                0.0       1061827.0
# 1     BAXTER JOHN C  267102.0          0.0          1295738.0       5634343.0
# 2    ELLIOTT STEVEN  170941.0          0.0                0.0        211725.0
# 3  CORDES WILLIAM R       0.0        764.0                0.0             0.0
# 4    HANNON KEVIN P  243293.0       1045.0                0.0        288682.0
#
#    exercised_stock_options      bonus  restricted_stock  \
# 0                      0.0   600000.0          585062.0
# 1                6680544.0  1200000.0         3942714.0
# 2                4890344.0   350000.0         1788391.0
# 3                 651850.0        0.0          386335.0
# 4                5538001.0  1500000.0          853064.0
#
#    shared_receipt_with_poi  restricted_stock_deferred  \
# 0                    702.0                        0.0
# ...

# %%
enron_df.dtypes
# Out:
# name                          object
# salary                       float64
# to_messages                  float64
# deferral_payments            float64
# total_payments               float64
# exercised_stock_options      float64
# bonus                        float64
# restricted_stock             float64
# shared_receipt_with_poi      float64
# restricted_stock_deferred    float64
# total_stock_value            float64
# expenses                     float64
# loan_advances                float64
# from_messages                float64
# other                        float64
# from_this_person_to_poi      float64
# poi                             bool
# director_fees                float64
# deferred_income              float64
# long_term_incentive          float64
# email_address                 object
# from_poi_to_this_person      float64
# dtype: object

# %%
enron_df.describe().transpose()
# Out:
#                            count          mean           std         min  \
# salary                     146.0  3.658114e+05  2.203575e+06         0.0
# to_messages                146.0  1.221589e+03  2.226771e+03         0.0
# deferral_payments          146.0  4.387965e+05  2.741325e+06   -102500.0
# total_payments             146.0  4.350622e+06  2.693448e+07         0.0
# exercised_stock_options    146.0  4.182736e+06  2.607040e+07         0.0
# bonus                      146.0  1.333474e+06  8.094029e+06         0.0
# restricted_stock           146.0  1.749257e+06  1.089995e+07  -2604490.0
# shared_receipt_with_poi    146.0  6.929863e+02  1.072969e+03         0.0
# restricted_stock_deferred  146.0  2.051637e+04  1.439661e+06  -7576788.0
# total_stock_value          146.0  5.846018e+06  3.624681e+07    -44093.0
# expenses                   146.0  7.074827e+04  4.327163e+05         0.0
# loan_advances              146.0  1.149658e+06  9.649342e+06         0.0
# ...

# %%
enron_df.poi.value_counts()
# Out:
# False    128
# True      18
# Name: poi, dtype: int64

# %%
# Code not need as values not in NaN format
# enron_df.fillna(0,inplace=True)
# enron_df.head()

# %%
# Drop Total Column
enron_df = enron_df[enron_df.name != 'TOTAL']

enron_df = enron_df[enron_df.name != 'THE TRAVEL AGENCY IN THE PARK']

# %%
# Drop non numeric columns
drop_columns = ['name', 'email_address']
enron_df.drop(drop_columns, inplace=True, axis=1)
enron_df.head()
# Out:
#      salary  to_messages  deferral_payments  total_payments  \
# 0  365788.0        807.0                0.0       1061827.0
# 1  267102.0          0.0          1295738.0       5634343.0
# 2  170941.0          0.0                0.0        211725.0
# 3       0.0        764.0                0.0             0.0
# 4  243293.0       1045.0                0.0        288682.0
#
#    exercised_stock_options      bonus  restricted_stock  \
# 0                      0.0   600000.0          585062.0
# 1                6680544.0  1200000.0         3942714.0
# 2                4890344.0   350000.0         1788391.0
# 3                 651850.0        0.0          386335.0
# 4                5538001.0  1500000.0          853064.0
#
#    shared_receipt_with_poi  restricted_stock_deferred  total_stock_value  \
# 0                    702.0                        0.0           585062.0
# 1                      0.0                        0.0         10623258.0
# ...

# %%
target = enron_df["poi"]
target_names = ["False", "True"]

# %%
data = enron_df.drop("poi", axis=1)
feature_names = data.columns
data.head()
# Out:
#      salary  to_messages  deferral_payments  total_payments  \
# 0  365788.0        807.0                0.0       1061827.0
# 1  267102.0          0.0          1295738.0       5634343.0
# 2  170941.0          0.0                0.0        211725.0
# 3       0.0        764.0                0.0             0.0
# 4  243293.0       1045.0                0.0        288682.0
#
#    exercised_stock_options      bonus  restricted_stock  \
# 0                      0.0   600000.0          585062.0
# 1                6680544.0  1200000.0         3942714.0
# 2                4890344.0   350000.0         1788391.0
# 3                 651850.0        0.0          386335.0
# 4                5538001.0  1500000.0          853064.0
#
#    shared_receipt_with_poi  restricted_stock_deferred  total_stock_value  \
# 0                    702.0                        0.0           585062.0
# 1                      0.0                        0.0         10623258.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
print(f"Decision Tree Classifier Score: {clf.score(X_test, y_test)}")
# Out:
# Decision Tree Classifier Score: 0.8333333333333334

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
print(f"Random Forest Tree Classifier Score: {rf.score(X_test, y_test)}")
# Out:
# Random Forest Tree Classifier Score: 0.8611111111111112

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.09594957631434899, 'other'),
#  (0.09471661250618571, 'exercised_stock_options'),
#  (0.08734739397813852, 'expenses'),
#  (0.07726754945617385, 'total_stock_value'),
#  (0.07563036277684614, 'bonus'),
#  (0.07341828229989, 'restricted_stock'),
#  (0.07286953317166983, 'salary'),
#  (0.06822792867199003, 'total_payments'),
#  (0.05389844171180736, 'from_this_person_to_poi'),
#  (0.053823988116779596, 'shared_receipt_with_poi'),
#  (0.05019058867892787, 'long_term_incentive'),
#  (0.048793060147505576, 'deferred_income'),
#  (0.048780591943553914, 'to_messages'),
#  (0.04313579011765865, 'from_poi_to_this_person'),
#  (0.037330728397941514, 'from_messages'),
#  (0.01600112056305928, 'deferral_payments'),
#  (0.0015007361059992637, 'restricted_stock_deferred'),
#  (0.0009112634286206514, 'loan_advances'),
#  (0.00020645161290322583, 'director_fees')]
